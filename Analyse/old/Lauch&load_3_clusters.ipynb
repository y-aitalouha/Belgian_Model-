# %% [markdown]
# # Remote Renewable Energy Hub
#
# ## The aim of this notebook is to launch Jocelyn's Belgium model

# %%
import os
import sys

project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))

belgian_data_folder = os.path.join(project_root, 'Data', 'Belgian_model')
plot_folder = os.path.join(project_root, 'Plots')
simulation_folder = os.path.join(project_root, 'Simulations')
result_folder = os.path.join(project_root, 'Results')
template_folder = os.path.join(project_root, 'Templates')
model_folder = os.path.join(project_root, 'Models GBOML')

 
sys.path.append(os.path.join(project_root, 'Modules'))

import GBOML_function as gf
import process_funct as pf

current_dir = os.getcwd()
result_dir = os.path.join(current_dir, 'Results')

# %% [markdown]
# # Set up

# %% [markdown]
# ### Class and functions

# %%
import argparse
import sys
import json
import time
from termcolor import colored
import logging
import sys
import pandas as pd
from tqdm import tqdm
from copy import deepcopy 
from gboml import GbomlGraph
from gboml.output import write_csv
from gboml.compiler import parse_file
from gboml.compiler.classes import Parameter, Expression, Constraint, Identifier, Node

class MyGbomlGraph(GbomlGraph):
    def update_global_parameter(self, param: Parameter):
        self.global_parameters = [x if x.name != param.name else param for x in self.global_parameters]
    def get_node_by_name(self, name: str):
        for node in self.list_nodes:
            if node.name == name:
                return node
        return None
    def get_hyperedge_by_name(self, name: str):
        for h in self.list_hyperedges:
            if h.name == name:
                return h
        return None
    
    def export_model_to_lp(self, filename: str):
        """
        Optional method: exports model to LP format (requires Gurobi model to be built first).
        """
        if hasattr(self, 'model'):  # Gurobi model exists after build_model()
            self.model.write(filename)
            print(f"✅ Model written to {filename}")
        else:
            print("⚠️ Gurobi model not found. Make sure build_model() was called.")

def get_named_symbol_in_list(l, name):
    for h in l:
        if h.name == name:
            return h
    return None

def get_node_in(element, name: str):
    if isinstance(element, GbomlGraph):
        l = element.list_nodes
    elif isinstance(element, Node):
        l = element.nodes
    else:
        raise Exception(f"Unknown class {element.__class__}")
    return get_named_symbol_in_list(l, name)
    

def get_hyperedge_in(element, name: str):
    if isinstance(element, GbomlGraph):
        l = element.list_hyperedges
    elif isinstance(element, Node):
        l = element.hyperedges
    else:
        raise Exception(f"Unknown class {element.__class__}")
    return get_named_symbol_in_list(l, name)

def update_parameter(symb, param):
    symb.parameters = [x if x.name != param.name else param for x in symb.parameters]

# %% [markdown]
# ### Set name period

# %%
def set_periodicity(TimeHorizon):
    
    if TimeHorizon >= 8760:
        if TimeHorizon % 8760 == 0:
            time = f"_{int(TimeHorizon/8760)}years.json"

        elif TimeHorizon % 8760 != 0:
            time = f"_{TimeHorizon}hours.json"
                
    if TimeHorizon < 8760:
            if TimeHorizon % 24 == 0:
                time = f"_{int(TimeHorizon/24)}days.json"
            
            else:
                time = f"_{TimeHorizon}hours.json"
                
    return time

# %% [markdown]
# ### Change parameters

# %%
def update_node_parameter(model, nodes_to_modify, new_capacity_value):
    """
    Updates the parameter for a list of nodes in a GBOML model.

    :param model: The loaded GBOML model (MyGbomlGraph)
    :param nodes_to_modify: List of node names (strings) to modify
    :param new_capacity_value: New value to assign to the 'max_capacity' parameter
    """
    for node_name in nodes_to_modify:
        node = model.get_node_by_name(node_name)
        if node is not None:
            param_updated = Parameter(name="max_capacity", value=new_capacity_value)
            update_parameter(node, param_updated)
            print(f"✅ max_capacity of {node_name} set to {new_capacity_value}")
        else:
            print(f"⚠️ Node {node_name} not found in the model.")
            
            
def update_subnode_parameter(model, cluster_name, subnode_names, param_name, new_value):
    """
    Updates a parameter for a list of subnodes within a given cluster node in a GBOML model.

    :param model: The loaded GBOML model (MyGbomlGraph)
    :param cluster_name: Name of the cluster (e.g., 'INLAND')
    :param subnode_names: List of subnode names (e.g., ['DME_PLANTS'])
    :param param_name: Parameter to update (e.g., 'max_capacity')
    :param new_value: Value to assign (should be a number)
    """
    cluster = model.get_node_by_name(cluster_name)
    if cluster is None:
        print(f"❌ Cluster node '{cluster_name}' not found.")
        return

    for subnode in cluster.nodes:
        if subnode.name in subnode_names:
            param = Parameter(param_name, Expression("literal", new_value))  # ✅ Fix: no str()
            update_parameter(subnode, param)
            print(f"✅ {cluster_name}.{subnode.name}: {param_name} set to {new_value}")

# %% [markdown]
# ### Build model

# %%
def build_model(TimeHorizon,model_name):
    program = parse_file(model_name)
    model = MyGbomlGraph()
    model.add_nodes_in_model(*deepcopy(program.get_nodes()))
    model.add_hyperedges_in_model(*deepcopy(program.get_links()))
    model.add_global_parameters(deepcopy(program.get_global_parameters()))
    model.set_timehorizon(TimeHorizon)

    return model


def build_and_solve(model, outfile=None):
    """
    Builds and solves the given GBOML model using Gurobi.
    If the solution is optimal, it exports a JSON and CSV with results.
    If infeasible, it prints the issue and exports a .lp file for debugging.

    :param model: GBOML model (MyGbomlGraph)
    :param outfile: Optional output filename (JSON). CSV will use same name.
    :return: Dictionary of results (or empty if infeasible)
    """
    print("🚧 Building model...")
    model.build_model(8)

    # Export LP version of the model for manual debug if needed
    model.export_model_to_lp("debug_model.lp")
    print("📤 Model exported to 'debug_model.lp'")

    print("🚀 Solving...")
    solution, objective, status, solver_info, cai, vai = model.solve_gurobi(
        details=os.path.join(model_folder, "gurobi_detail.txt"),
        opt_file=os.path.join(model_folder, "gurobi.opt")
    )

    print("🧠 Gurobi status:", status)
    if "OPTIMAL" not in str(status).upper():
        print("❌ No feasible solution found.")
        return {}

    print("✅ Optimal solution found.")

    out = model.turn_solution_to_dictionary(solver_info, status, solution, objective, cai, vai)
    outlist = model.turn_solution_to_list(solution, constraints_info=cai)
    list_names = [x[0] for x in outlist]
    list_val = [x[1] for x in outlist]

    if outfile:
        with open(outfile, 'w') as f_json:
            json.dump(out, f_json, indent=4, sort_keys=True)
        write_csv(outfile.replace(".json", ".csv"), list_names, list_val, transpose=True)
        print(f"📁 Results saved: {outfile} and CSV version.")

    return out

# %% [markdown]
# ### Scenario maker

# %%
def scenario_maker(clusters, nodes, params):
    """
    Generates a list of dictionaries (modifs) to apply parameter modifications
    to a combination of clusters and subnodes in a GBOML model.

    :param clusters: list of cluster names (e.g., ["INLAND", "ZEEBRUGGE"])
    :param nodes: list of subnode names (e.g., ["DME_PLANTS", "ETH_PLANTS"])
    :param params: dictionary of parameters to modify (e.g., {"max_capacity": 0})
    :return: list of formatted dictionaries for scenario modification
    """
    modifs = []
    for cluster in clusters:
        for node in nodes:
            modifs.append({
                "cluster": cluster,
                "node": node,
                "params": params.copy()
            })
    return modifs



def run_scenarios(base_model, file_path, period, new_scenario=None, modifications=None, scenario_name=None):
    """
    Runs a GBOML simulation scenario. Optionally modifies certain node parameters.

    :param base_model: Compiled GBOML model (MyGbomlGraph)
    :param file_path: Path to save output files (with trailing slash)
    :param period: Suffix for the output file (e.g. _2030)
    :param new_scenario: Optional name of the scenario (used as suffix in filenames)
    :param modifications: Optional list of parameter changes (only if new_scenario is not None). Format:
                          [{"cluster": "INLAND", "node": "DME_PLANTS", "params": {"max_capacity": 0}}]
    """
    from copy import deepcopy
    import time

    if new_scenario:
        scenario = new_scenario
    elif scenario_name:
        scenario = scenario_name
    else:
        scenario = "base" 
    
    print(f"\n🔁 Running scenario: " + colored(f'{scenario}', 'white', 'on_blue'))
    start_time = time.time()

    model = deepcopy(base_model)

    if new_scenario and modifications:
        for item in modifications:
            cluster_name = item["cluster"]
            node_name = item["node"]
            for param_name, value in item["params"].items():
                try:
                    update_subnode_parameter(model, cluster_name, [node_name], param_name, value)
                except Exception as e:
                    print(colored(f"⚠️ Skipped modification: {cluster_name}.{node_name}.{param_name} – {e}", 'yellow'))

    out_path = os.path.join(file_path, f"scenario_{scenario}_{period}.json")
    results = build_and_solve(model, outfile=out_path)

    duration = time.time() - start_time
    print(f"✅ Scenario '{scenario}' completed in {duration:.1f} seconds.")

    return results

# %% [markdown]
# # MAIN

# %% [markdown]
# - Timehorizon setting

# %%
TimeHorizon = 8760
# TimeHorizon = 1000 # 1 week
# TimeHorizon = 24*7 # 1 week

period = set_periodicity(TimeHorizon)

# %% [markdown]
# ### Model 3 clusters from article

# %%
file_3_clusters_efuel_INLAND = "be_model_3_clusters_all_efuels.txt" 

model_3_clusters_efuel_INLAND = build_model(TimeHorizon, os.path.join(model_folder, file_3_clusters_efuel_INLAND))

# %%
three_clusters_efuel_INLAND_scenario = run_scenarios(model_3_clusters_efuel_INLAND, file_path=simulation_folder, period=period, scenario_name='efuel_INLAND_ZEEBRUGGE')
# Out:
# 🔁 Running scenario: efuel_INLAND_ZEEBRUGGE
# 🚧 Building model...
# Check variables of node INLAND : --- 0.0 seconds ---
# Check variables of node DEMAND : --- 0.0 seconds ---
# Check variables of node BALANCE : --- 0.0 seconds ---
# Check variables of node CO2_EXPORT : --- 0.0010025501251220703 seconds ---
# Check variables of node CO2_STORAGE : --- 0.0 seconds ---
# Check variables of node PCCC_SMR : --- 0.0 seconds ---
# Check variables of node PCCC_OCGT : --- 0.0009965896606445312 seconds ---
# Check variables of node PCCC_CCGT : --- 0.0 seconds ---
# Check variables of node PCCC_CHP : --- 0.0006413459777832031 seconds ---
# Check variables of node PCCC_WS : --- 0.0002090930938720703 seconds ---
# Check variables of node PCCC_BM : --- 0.0 seconds ---
# Check variables of node DAC : --- 0.0 seconds ---
# Check variables of node PCCC_MEOH : --- 0.0 seconds ---
# Check variables of node PCCC_FT : --- 0.0006833076477050781 seconds ---
# Check variables of node PCCC_DME : --- 0.0 seconds ---
# Check variables of node METHANOL_STORAGE : --- 0.0 seconds ---
# Check variables of node METHANOL_PLANTS : --- 0.0010974407196044922 seconds ---
# Check variables of node PETROL_STORAGE : --- 0.0004096031188964844 seconds ---
# Check variables of node REFINED_PETROL_STORAGE : --- 0.0 seconds ---
# Check variables of node REFINERY : --- 0.0 seconds ---
# Check variables of node FT_PLANTS : --- 0.0 seconds ---
# Check variables of node PROPANOL_STORAGE : --- 0.0 seconds ---
# Check variables of node ETHANOL_STORAGE : --- 0.0 seconds ---
# Check variables of node CELLETH_PLANTS : --- 0.0 seconds ---
# Check variables of node BIOETH_PLANTS : --- 0.0 seconds ---
# Check variables of node ETH_PROP_PLANTS : --- 0.0 seconds ---
# Check variables of node DME_STORAGE : --- 0.0 seconds ---
# Check variables of node DME_PLANTS : --- 0.0 seconds ---
# Check variables of node H2O_STORAGE : --- 0.0 seconds ---
# Check variables of node DESALINATION : --- 0.0 seconds ---
# Check variables of node H2_STORAGE : --- 0.0 seconds ---
# Check variables of node SMR : --- 0.0 seconds ---
# Check variables of node H2_INTERCONNECTION_NL : --- 0.0 seconds ---
# Check variables of node H2_INTERCONNECTION_DE : --- 0.0 seconds ---
# Check variables of node H2_INTERCONNECTION : --- 0.0 seconds ---
# Check variables of node LINEPACK_NG : --- 0.0 seconds ---
# Check variables of node NG_STORAGE : --- 0.0 seconds ---
# Check variables of node METHANATION : --- 0.0 seconds ---
# Check variables of node BIOMETHANE : --- 0.0 seconds ---
# Check variables of node NG_INTERCONNECTION_DE : --- 0.0 seconds ---
# Check variables of node NG_INTERCONNECTION_FR : --- 0.0 seconds ---
# Check variables of node NG_INTERCONNECTION_NL : --- 0.0 seconds ---
# Check variables of node LOAD_SHEDDING_UNLIM : --- 0.0 seconds ---
# Check variables of node LOAD_SHEDDING_8 : --- 0.0 seconds ---
# Check variables of node LOAD_SHEDDING_4 : --- 0.0 seconds ---
# Check variables of node LOAD_SHEDDING_2 : --- 0.0 seconds ---
# Check variables of node LOAD_SHEDDING_1 : --- 0.0 seconds ---
# Check variables of node LOAD_SHIFTING : --- 0.0 seconds ---
# Check variables of node FUEL_CELLS : --- 0.0 seconds ---
# Check variables of node BATTERIES : --- 0.0 seconds ---
# Check variables of node PUMPED_HYDRO : --- 0.0 seconds ---
# Check variables of node ELECTROLYSIS_PLANTS : --- 0.0 seconds ---
# Check variables of node OCGT : --- 0.0 seconds ---
# Check variables of node CCGT : --- 0.0 seconds ---
# Check variables of node CHP : --- 0.0 seconds ---
# Check variables of node WASTE : --- 0.0 seconds ---
# Check variables of node BIOMASS : --- 0.0 seconds ---
# Check variables of node NUCLEAR : --- 0.0 seconds ---
# Check variables of node WIND_ONSHORE : --- 0.0 seconds ---
# Check variables of node PV : --- 0.0 seconds ---
# Check hyperlink BALANCES : --- 0.0 seconds ---
# Check hyperlink CO2_CAPTURE_SMR : --- 0.0 seconds ---
# Check hyperlink CO2_CAPTURE_OCGT : --- 0.0 seconds ---
# Check hyperlink CO2_CAPTURE_CCGT : --- 0.0 seconds ---
# Check hyperlink CO2_CAPTURE_CHP : --- 0.0 seconds ---
# Check hyperlink CO2_CAPTURE_WS : --- 0.0 seconds ---
# Check hyperlink CO2_CAPTURE_BM : --- 0.0 seconds ---
# Check hyperlink CO2_CAPTURE_MEOH : --- 0.0 seconds ---
# Check hyperlink CO2_CAPTURE_FT : --- 0.0 seconds ---
# Check hyperlink CO2_CAPTURE_DME : --- 0.0 seconds ---
# Check variables of node FRANCE : --- 0.0 seconds ---
# Check variables of node PRODUCTION : --- 0.0 seconds ---
# Check variables of node NUCLEAR : --- 0.0 seconds ---
# Check variables of node WIND_ONSHORE : --- 0.0011222362518310547 seconds ---
# Check variables of node WIND_OFFSHORE : --- 0.0 seconds ---
# Check variables of node PV : --- 0.0 seconds ---
# Check hyperlink IMPORT : --- 0.0 seconds ---
# Check variables of node LUXEMBOURG : --- 0.0 seconds ---
# Check variables of node PRODUCTION : --- 0.0 seconds ---
# Check variables of node WIND_ONSHORE : --- 0.0 seconds ---
# Check variables of node WIND_OFFSHORE : --- 0.0 seconds ---
# Check variables of node PV : --- 0.0 seconds ---
# Check hyperlink IMPORT : --- 0.0 seconds ---
# Check variables of node DEUTSCHLAND : --- 0.0 seconds ---
# Check variables of node PRODUCTION : --- 0.0 seconds ---
# Check variables of node WIND_ONSHORE : --- 0.0 seconds ---
# Check variables of node WIND_OFFSHORE : --- 0.0 seconds ---
# Check variables of node PV : --- 0.0 seconds ---
# Check hyperlink IMPORT : --- 0.0 seconds ---
# Check variables of node NETHERLANDS : --- 0.0 seconds ---
# Check variables of node PRODUCTION : --- 0.0 seconds ---
# Check variables of node WIND_ONSHORE : --- 0.0 seconds ---
# Check variables of node WIND_OFFSHORE : --- 0.0 seconds ---
# Check variables of node PV : --- 0.0009965896606445312 seconds ---
# Check hyperlink IMPORT : --- 0.0 seconds ---
# Check variables of node TRUCK_KEROSENE_ZB_INL : --- 0.0 seconds ---
# Check variables of node TRUCK_GASOLINE_ZB_INL : --- 0.0 seconds ---
# Check variables of node TRUCK_DIESEL_ZB_INL : --- 0.0 seconds ---
# Check variables of node TRUCK_MEOH_ZB_INL : --- 0.0 seconds ---
# Check variables of node TRUCK_ETH_ZB_INL : --- 0.0 seconds ---
# Check variables of node TRUCK_PROP_ZB_INL : --- 0.0 seconds ---
# Check variables of node TRUCK_DME_ZB_INL : --- 0.0010058879852294922 seconds ---
# Check variables of node PIPE_H2_ZB_INL : --- 0.0 seconds ---
# Check variables of node PIPE_NG_ZB_INL : --- 0.0 seconds ---
# Check variables of node HV_ZB_INL : --- 0.0 seconds ---
# Check variables of node ZEEBRUGGE : --- 0.0 seconds ---
# Check variables of node BALANCE : --- 0.0 seconds ---
# Check variables of node METHANOL_STORAGE : --- 0.0009903907775878906 seconds ---
# Check variables of node METHANOL_PLANTS : --- 0.0 seconds ---
# Check variables of node PETROL_STORAGE : --- 0.0 seconds ---
# Check variables of node REFINED_PETROL_STORAGE : --- 0.0010025501251220703 seconds ---
# Check variables of node REFINERY : --- 0.0 seconds ---
# Check variables of node FT_PLANTS : --- 0.0 seconds ---
# Check variables of node PROPANOL_STORAGE : --- 0.0010051727294921875 seconds ---
# Check variables of node ETHANOL_STORAGE : --- 0.0 seconds ---
# Check variables of node CELLETH_PLANTS : --- 0.0 seconds ---
# Check variables of node BIOETH_PLANTS : --- 0.0009953975677490234 seconds ---
# Check variables of node ETH_PROP_PLANTS : --- 0.000997304916381836 seconds ---
# Check variables of node DME_STORAGE : --- 0.0 seconds ---
# Check variables of node DME_PLANTS : --- 0.0010044574737548828 seconds ---
# Check variables of node H2O_STORAGE : --- 0.0 seconds ---
# Check variables of node DESALINATION : --- 0.0 seconds ---
# Check variables of node PCCC_MEOH : --- 0.0 seconds ---
# Check variables of node PCCC_FT : --- 0.0 seconds ---
# Check variables of node PCCC_DME : --- 0.0009999275207519531 seconds ---
# Check variables of node DAC : --- 0.0 seconds ---
# Check variables of node H2_STORAGE : --- 0.0 seconds ---
# Check variables of node H2_INTERCONNECTION_FR : --- 0.0 seconds ---
# Check variables of node H2_INTERCONNECTION_UK : --- 0.0 seconds ---
# Check variables of node H2_INTERCONNECTION_NV : --- 0.0 seconds ---
# Check variables of node H2_INTERCONNECTION : --- 0.0 seconds ---
# Check variables of node REGAS_H2 : --- 0.0 seconds ---
# Check variables of node ELECTROLYSIS_PLANTS : --- 0.0 seconds ---
# Check variables of node METHANATION : --- 0.0 seconds ---
# Check variables of node REGAS_GREEN : --- 0.0 seconds ---
# Check variables of node NG_INTERCONNECTION_FR : --- 0.0 seconds ---
# Check variables of node NG_INTERCONNECTION_UK : --- 0.0009999275207519531 seconds ---
# Check variables of node NG_INTERCONNECTION_NV : --- 0.0 seconds ---
# Check variables of node REGAS : --- 0.0 seconds ---
# Check variables of node FUEL_CELLS : --- 0.0 seconds ---
# Check variables of node BATTERIES : --- 0.0009999275207519531 seconds ---
# Check hyperlink BALANCES : --- 0.0 seconds ---
# Check hyperlink CO2_CAPTURE_MEOH : --- 0.0 seconds ---
# Check hyperlink CO2_CAPTURE_FT : --- 0.0 seconds ---
# Check hyperlink CO2_CAPTURE_DME : --- 0.0 seconds ---
# Check variables of node UNITED_KINGDOM : --- 0.0009992122650146484 seconds ---
# Check variables of node PRODUCTION : --- 0.0 seconds ---
# Check variables of node NUCLEAR : --- 0.0 seconds ---
# Check variables of node WIND_ONSHORE : --- 0.00045037269592285156 seconds ---
# Check variables of node WIND_OFFSHORE : --- 0.0 seconds ---
# Check variables of node PV : --- 0.0 seconds ---
# Check hyperlink IMPORT : --- 0.0 seconds ---
# Check variables of node DENMARK : --- 0.0 seconds ---
# Check variables of node PRODUCTION : --- 0.0 seconds ---
# Check variables of node WIND_ONSHORE : --- 0.0 seconds ---
# Check variables of node WIND_OFFSHORE : --- 0.001035451889038086 seconds ---
# Check variables of node PV : --- 0.0 seconds ---
# Check hyperlink IMPORT : --- 0.0 seconds ---
# Check variables of node HV_OFF_ZB : --- 0.0 seconds ---
# Check variables of node OFFSHORE : --- 0.0 seconds ---
# Check variables of node BALANCE : --- 0.0 seconds ---
# Check variables of node H2O_STORAGE : --- 0.0 seconds ---
# Check variables of node DESALINATION : --- 0.0010805130004882812 seconds ---
# Check variables of node H2_STORAGE : --- 0.0 seconds ---
# Check variables of node ELECTROLYSIS_PLANTS : --- 0.0 seconds ---
# Check variables of node FUEL_CELLS : --- 0.0 seconds ---
# Check variables of node BATTERIES : --- 0.0 seconds ---
# Check variables of node WIND_OFFSHORE : --- 0.0 seconds ---
# Check hyperlink BALANCES : --- 0.0 seconds ---
# Check hyperlink CO2_QUOTA : --- 0.0 seconds ---
# Warning : Hyperedge constraint using variables from a single node at line 1693
# Warning : Hyperedge constraint using variables from a single node at line 1695
# Warning : Hyperedge constraint using variables from a single node at line 1698
# Warning : Hyperedge constraint using variables from a single node at line 1703
# Check hyperlink INLAND_BALANCE : --- 0.0 seconds ---
# Check hyperlink DEMAND_SPLIT : --- 0.0 seconds ---
# Warning : Hyperedge constraint using variables from a single node at line 876
# Check hyperlink ZEEBRUGGE_BALANCE : --- 0.0 seconds ---
# Check hyperlink OFFSHORE_BALANCE : --- 0.0 seconds ---
# ⚠️ Gurobi model not found. Make sure build_model() was called.
# 📤 Model exported to 'debug_model.lp'
# 🚀 Solving...
# Set parameter Username
# Academic license - for non-commercial use only - expires 2026-05-05
#
# Reading Gurobi options from file gurobi.opt
# Options file not found
#
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (win64)
#
# CPU model: 12th Gen Intel(R) Core(TM) i7-1255U, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 8100293 rows, 3874613 columns and 16994560 nonzeros
# Model fingerprint: 0x0730a6dd
# Coefficient statistics:
#   Matrix range     [1e-05, 9e+03]
#   Objective range  [1e-06, 3e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e-05, 9e+05]
# Presolve removed 5870325 rows and 2378367 columns (presolve time = 5s) ...
# Presolve removed 5949196 rows and 2396667 columns
# Presolve time: 20.75s
# Presolved: 2151097 rows, 1495464 columns, 7423121 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Elapsed ordering time = 9s
# Elapsed ordering time = 10s
# Ordering time: 26.99s
#
# Barrier statistics:
#  Dense cols : 94
#  AA' NZ     : 1.278e+07
#  Factor NZ  : 1.017e+08 (roughly 2.3 GB of memory)
#  Factor Ops : 3.399e+10 (roughly 1 second per iteration)
#  Threads    : 8
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   9.83305247e+09 -1.72033031e+13  2.94e+08 1.19e+00  4.32e+07    54s
#    1   9.94330610e+09 -1.64798053e+13  2.89e+08 5.71e+02  4.15e+07    56s
#    2   1.02171855e+10 -1.43966043e+13  2.74e+08 4.91e+02  3.74e+07    58s
#    3   1.07682592e+10 -1.29834380e+13  2.34e+08 4.52e+02  3.23e+07    61s
#    4   1.09177832e+10 -9.84570400e+12  2.12e+08 3.48e+02  2.75e+07    63s
#    5   8.62278560e+09 -5.71316962e+12  1.47e+08 2.10e+02  2.10e+07    66s
#    6   3.02793140e+09 -2.77836532e+12  4.63e+07 5.80e+01  6.97e+06    68s
#    7   1.03238341e+09 -1.29002102e+12  1.10e+07 4.28e+00  1.71e+06    71s
#    8   8.26527718e+08 -9.22820420e+11  5.24e+06 1.86e+00  8.41e+05    74s
#    9   7.49002776e+08 -4.15855843e+11  3.50e+06 2.12e-01  4.55e+05    77s
#   10   6.21410584e+08 -3.71599040e+11  2.09e+06 1.76e-01  2.95e+05    79s
#    60966 DPushes remaining with DInf 2.6592851e-01               526s
#    58742 DPushes remaining with DInf 2.6592854e-01               534s
#    57928 DPushes remaining with DInf 2.4573852e-01               537s
#    56016 DPushes remaining with DInf 2.4571707e-01               541s
#    54600 DPushes remaining with DInf 2.4571707e-01               546s
#    53177 DPushes remaining with DInf 2.4380061e-01               552s
#    51743 DPushes remaining with DInf 2.3226232e-01               556s
#    49598 DPushes remaining with DInf 2.2111644e-01               561s
#    47474 DPushes remaining with DInf 2.1970811e-01               566s
#    44631 DPushes remaining with DInf 1.2128877e-01               572s
#    42506 DPushes remaining with DInf 1.2128877e-01               575s
#    37004 DPushes remaining with DInf 2.4281093e-02               581s
#    35588 DPushes remaining with DInf 2.3744446e-02               586s
#    30090 DPushes remaining with DInf 1.8249039e-02               590s
#     1548 DPushes remaining with DInf 4.6868648e-03               596s
#        0 DPushes remaining with DInf 4.6913947e-03               598s
#
#   352345 PPushes remaining with PInf 2.2105504e-01               599s
#   184859 PPushes remaining with PInf 6.7158413e-01               618s
#   163200 PPushes remaining with PInf 7.0252308e-01               624s
#   158035 PPushes remaining with PInf 1.3588020e+00               629s
#   153985 PPushes remaining with PInf 1.3509385e+00               631s
#   105287 PPushes remaining with PInf 1.2868125e+00               636s
#   100577 PPushes remaining with PInf 1.2855181e+00               641s
#    94264 PPushes remaining with PInf 1.2852203e+00               646s
#    63580 PPushes remaining with PInf 1.1849002e+00               675s
#    60679 PPushes remaining with PInf 1.1849002e+00               684s
#    59971 PPushes remaining with PInf 1.1849263e+00               686s
#    57847 PPushes remaining with PInf 1.1849002e+00               692s
#    30134 PPushes remaining with PInf 1.2264565e+00               698s
#     7558 PPushes remaining with PInf 1.1260131e+00               755s
#        0 PPushes remaining with PInf 0.0000000e+00               759s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 1.0672732e+02    759s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   581366    9.8596767e+05   0.000000e+00   1.067273e+02    760s
#   582074    9.8596767e+05   0.000000e+00   5.516180e+01    774s
#   582782    9.8596767e+05   0.000000e+00   6.307620e+02    787s
#   583490    9.8596767e+05   0.000000e+00   3.770172e+02    800s
#   584198    9.8596767e+05   0.000000e+00   1.654757e+02    812s
#   584906    9.8596767e+05   0.000000e+00   2.894958e+00    825s
#   585615    9.8596163e+05   0.000000e+00   1.588129e-02    833s
#   586323    9.8596163e+05   0.000000e+00   6.176140e-03    846s
#   587031    9.8596163e+05   0.000000e+00   4.425298e-03    861s
#   587739    9.8596163e+05   0.000000e+00   3.038053e-03    882s
#   588447    9.8596163e+05   0.000000e+00   1.939975e-03    904s
#   589155    9.8596163e+05   0.000000e+00   1.041900e-03    926s
#   589302    9.8596163e+05   0.000000e+00   0.000000e+00    932s
#
# Solved with barrier
#   589302    9.8596163e+05   0.000000e+00   5.024315e+03    940s
#   590587    9.8596163e+05   0.000000e+00   6.739833e-03    981s
#   591434    9.8596163e+05   0.000000e+00   3.378493e-05   1017s
# Extra simplex iterations after uncrush: 12
#   591446    9.8596163e+05   0.000000e+00   0.000000e+00   1024s
#
# Solved in 591446 iterations and 1024.23 seconds (1044.05 work units)
# Optimal objective  9.859616284e+05
# 🧠 Gurobi status: optimal
# ✅ Optimal solution found.
# 📁 Results saved: c:\Users\yaita\OneDrive\Bureau\Master Thesis\Belgium Model - efuel integrated\Simulations\scenario_efuel_INLAND_ZEEBRUGGE__1years.json.json and CSV version.
# ✅ Scenario 'efuel_INLAND_ZEEBRUGGE' completed in 1082.6 seconds.

# %%
clusters = ["INLAND", "ZEEBRUGGE"]
nodes = [ "FT_PLANTS", "REFINERY", "REFINED_PETROL_STORAGE", "PETROL_STORAGE"]
# nodes = ["ETH_PLANTS","BIOETH_PLANTS", "CELLETH_PLANTS", "ETHANOL_STORAGE"]
params = {"max_capacity": 0, "pre_installed_capacity": 0}

modifs = scenario_maker(clusters, nodes, params)
modifs_table = pf.transform_dict_into_table_several_column(modifs)
# Out:
#      cluster                    node  \
# 0     INLAND               FT_PLANTS
# 1     INLAND                REFINERY
# 2     INLAND  REFINED_PETROL_STORAGE
# 3     INLAND          PETROL_STORAGE
# 4  ZEEBRUGGE               FT_PLANTS
# 5  ZEEBRUGGE                REFINERY
# 6  ZEEBRUGGE  REFINED_PETROL_STORAGE
# 7  ZEEBRUGGE          PETROL_STORAGE
#
#                                              params
# 0  {'max_capacity': 0, 'pre_installed_capacity': 0}
# 1  {'max_capacity': 0, 'pre_installed_capacity': 0}
# 2  {'max_capacity': 0, 'pre_installed_capacity': 0}
# 3  {'max_capacity': 0, 'pre_installed_capacity': 0}
# 4  {'max_capacity': 0, 'pre_installed_capacity': 0}
# 5  {'max_capacity': 0, 'pre_installed_capacity': 0}
# 6  {'max_capacity': 0, 'pre_installed_capacity': 0}
# 7  {'max_capacity': 0, 'pre_installed_capacity': 0}

# %%
three_clusters_efuel_INLAND_scenario = run_scenarios(model_3_clusters_efuel_INLAND, file_path=simulation_folder, period=period, new_scenario="efuel_INLAND_ZEEBRUGGE_no_ft", modifications=modifs)
# Out:
# 🔁 Running scenario: efuel_INLAND_ZEEBRUGGE_no_ft
# ✅ INLAND.FT_PLANTS: max_capacity set to 0
# ✅ INLAND.FT_PLANTS: pre_installed_capacity set to 0
# ✅ INLAND.REFINERY: max_capacity set to 0
# ✅ INLAND.REFINERY: pre_installed_capacity set to 0
# ✅ INLAND.REFINED_PETROL_STORAGE: max_capacity set to 0
# ✅ INLAND.REFINED_PETROL_STORAGE: pre_installed_capacity set to 0
# ✅ INLAND.PETROL_STORAGE: max_capacity set to 0
# ✅ INLAND.PETROL_STORAGE: pre_installed_capacity set to 0
# ✅ ZEEBRUGGE.FT_PLANTS: max_capacity set to 0
# ✅ ZEEBRUGGE.FT_PLANTS: pre_installed_capacity set to 0
# ✅ ZEEBRUGGE.REFINERY: max_capacity set to 0
# ✅ ZEEBRUGGE.REFINERY: pre_installed_capacity set to 0
# ✅ ZEEBRUGGE.REFINED_PETROL_STORAGE: max_capacity set to 0
# ✅ ZEEBRUGGE.REFINED_PETROL_STORAGE: pre_installed_capacity set to 0
# ✅ ZEEBRUGGE.PETROL_STORAGE: max_capacity set to 0
# ✅ ZEEBRUGGE.PETROL_STORAGE: pre_installed_capacity set to 0
# 🚧 Building model...
# Check variables of node INLAND : --- 0.0 seconds ---
# Check variables of node DEMAND : --- 0.0 seconds ---
# Check variables of node BALANCE : --- 0.0 seconds ---
# Check variables of node CO2_EXPORT : --- 0.0 seconds ---
# Check variables of node CO2_STORAGE : --- 0.0 seconds ---
# Check variables of node PCCC_SMR : --- 0.0 seconds ---
# Check variables of node PCCC_OCGT : --- 0.0 seconds ---
# Check variables of node PCCC_CCGT : --- 0.0 seconds ---
# Check variables of node PCCC_CHP : --- 0.0 seconds ---
# Check variables of node PCCC_WS : --- 0.0 seconds ---
# Check variables of node PCCC_BM : --- 0.0 seconds ---
# Check variables of node DAC : --- 0.0 seconds ---
# Check variables of node PCCC_MEOH : --- 0.0 seconds ---
# Check variables of node PCCC_FT : --- 0.0 seconds ---
# Check variables of node PCCC_DME : --- 0.0 seconds ---
# Check variables of node METHANOL_STORAGE : --- 0.0 seconds ---
# Check variables of node METHANOL_PLANTS : --- 0.0 seconds ---
# Check variables of node PETROL_STORAGE : --- 0.0 seconds ---
# Check variables of node REFINED_PETROL_STORAGE : --- 0.0 seconds ---
# Check variables of node REFINERY : --- 0.0 seconds ---
# Check variables of node FT_PLANTS : --- 0.0 seconds ---
# Check variables of node PROPANOL_STORAGE : --- 0.0 seconds ---
# Check variables of node ETHANOL_STORAGE : --- 0.0 seconds ---
# Check variables of node CELLETH_PLANTS : --- 0.0 seconds ---
# Check variables of node BIOETH_PLANTS : --- 0.0 seconds ---
# Check variables of node ETH_PROP_PLANTS : --- 0.0 seconds ---
# Check variables of node DME_STORAGE : --- 0.0 seconds ---
# Check variables of node DME_PLANTS : --- 0.015062093734741211 seconds ---
# Check variables of node H2O_STORAGE : --- 0.0 seconds ---
# Check variables of node DESALINATION : --- 0.0 seconds ---
# Check variables of node H2_STORAGE : --- 0.001203775405883789 seconds ---
# Check variables of node SMR : --- 0.0 seconds ---
# Check variables of node H2_INTERCONNECTION_NL : --- 0.0 seconds ---
# Check variables of node H2_INTERCONNECTION_DE : --- 0.0 seconds ---
# Check variables of node H2_INTERCONNECTION : --- 0.0 seconds ---
# Check variables of node LINEPACK_NG : --- 0.0 seconds ---
# Check variables of node NG_STORAGE : --- 0.0 seconds ---
# Check variables of node METHANATION : --- 0.0 seconds ---
# Check variables of node BIOMETHANE : --- 0.0 seconds ---
# Check variables of node NG_INTERCONNECTION_DE : --- 0.0 seconds ---
# Check variables of node NG_INTERCONNECTION_FR : --- 0.0 seconds ---
# Check variables of node NG_INTERCONNECTION_NL : --- 0.0 seconds ---
# Check variables of node LOAD_SHEDDING_UNLIM : --- 0.0 seconds ---
# Check variables of node LOAD_SHEDDING_8 : --- 0.0 seconds ---
# Check variables of node LOAD_SHEDDING_4 : --- 0.0 seconds ---
# Check variables of node LOAD_SHEDDING_2 : --- 0.0 seconds ---
# Check variables of node LOAD_SHEDDING_1 : --- 0.0 seconds ---
# Check variables of node LOAD_SHIFTING : --- 0.0 seconds ---
# Check variables of node FUEL_CELLS : --- 0.0 seconds ---
# Check variables of node BATTERIES : --- 0.0 seconds ---
# Check variables of node PUMPED_HYDRO : --- 0.0 seconds ---
# Check variables of node ELECTROLYSIS_PLANTS : --- 0.0 seconds ---
# Check variables of node OCGT : --- 0.0 seconds ---
# Check variables of node CCGT : --- 0.0 seconds ---
# Check variables of node CHP : --- 0.0 seconds ---
# Check variables of node WASTE : --- 0.0 seconds ---
# Check variables of node BIOMASS : --- 0.0 seconds ---
# Check variables of node NUCLEAR : --- 0.005279541015625 seconds ---
# Check variables of node WIND_ONSHORE : --- 0.0 seconds ---
# Check variables of node PV : --- 0.0 seconds ---
# Check hyperlink BALANCES : --- 0.0 seconds ---
# Check hyperlink CO2_CAPTURE_SMR : --- 0.0 seconds ---
# Check hyperlink CO2_CAPTURE_OCGT : --- 0.0 seconds ---
# Check hyperlink CO2_CAPTURE_CCGT : --- 0.0 seconds ---
# Check hyperlink CO2_CAPTURE_CHP : --- 0.0 seconds ---
# Check hyperlink CO2_CAPTURE_WS : --- 0.0 seconds ---
# Check hyperlink CO2_CAPTURE_BM : --- 0.0 seconds ---
# Check hyperlink CO2_CAPTURE_MEOH : --- 0.0 seconds ---
# Check hyperlink CO2_CAPTURE_FT : --- 0.0 seconds ---
# Check hyperlink CO2_CAPTURE_DME : --- 0.0 seconds ---
# Check variables of node FRANCE : --- 0.0 seconds ---
# Check variables of node PRODUCTION : --- 0.0 seconds ---
# Check variables of node NUCLEAR : --- 0.0 seconds ---
# Check variables of node WIND_ONSHORE : --- 0.0 seconds ---
# Check variables of node WIND_OFFSHORE : --- 0.0 seconds ---
# Check variables of node PV : --- 0.0 seconds ---
# Check hyperlink IMPORT : --- 0.0 seconds ---
# Check variables of node LUXEMBOURG : --- 0.0 seconds ---
# Check variables of node PRODUCTION : --- 0.0 seconds ---
# Check variables of node WIND_ONSHORE : --- 0.0 seconds ---
# Check variables of node WIND_OFFSHORE : --- 0.0 seconds ---
# Check variables of node PV : --- 0.0 seconds ---
# Check hyperlink IMPORT : --- 0.0 seconds ---
# Check variables of node DEUTSCHLAND : --- 0.0 seconds ---
# Check variables of node PRODUCTION : --- 0.0 seconds ---
# Check variables of node WIND_ONSHORE : --- 0.0 seconds ---
# Check variables of node WIND_OFFSHORE : --- 0.0 seconds ---
# Check variables of node PV : --- 0.0 seconds ---
# Check hyperlink IMPORT : --- 0.0 seconds ---
# Check variables of node NETHERLANDS : --- 0.0 seconds ---
# Check variables of node PRODUCTION : --- 0.0 seconds ---
# Check variables of node WIND_ONSHORE : --- 0.0 seconds ---
# Check variables of node WIND_OFFSHORE : --- 0.0 seconds ---
# Check variables of node PV : --- 0.0 seconds ---
# Check hyperlink IMPORT : --- 0.0 seconds ---
# Check variables of node TRUCK_KEROSENE_ZB_INL : --- 0.0 seconds ---
# Check variables of node TRUCK_GASOLINE_ZB_INL : --- 0.0 seconds ---
# Check variables of node TRUCK_DIESEL_ZB_INL : --- 0.0 seconds ---
# Check variables of node TRUCK_MEOH_ZB_INL : --- 0.006163120269775391 seconds ---
# Check variables of node TRUCK_ETH_ZB_INL : --- 0.0 seconds ---
# Check variables of node TRUCK_PROP_ZB_INL : --- 0.0 seconds ---
# Check variables of node TRUCK_DME_ZB_INL : --- 0.0010101795196533203 seconds ---
# Check variables of node PIPE_H2_ZB_INL : --- 0.0005171298980712891 seconds ---
# Check variables of node PIPE_NG_ZB_INL : --- 0.0 seconds ---
# Check variables of node HV_ZB_INL : --- 0.0 seconds ---
# Check variables of node ZEEBRUGGE : --- 0.0 seconds ---
# Check variables of node BALANCE : --- 0.0 seconds ---
# Check variables of node METHANOL_STORAGE : --- 0.0 seconds ---
# Check variables of node METHANOL_PLANTS : --- 0.0 seconds ---
# Check variables of node PETROL_STORAGE : --- 0.0 seconds ---
# Check variables of node REFINED_PETROL_STORAGE : --- 0.0 seconds ---
# Check variables of node REFINERY : --- 0.0 seconds ---
# Check variables of node FT_PLANTS : --- 0.0 seconds ---
# Check variables of node PROPANOL_STORAGE : --- 0.0 seconds ---
# Check variables of node ETHANOL_STORAGE : --- 0.0 seconds ---
# Check variables of node CELLETH_PLANTS : --- 0.0 seconds ---
# Check variables of node BIOETH_PLANTS : --- 0.0 seconds ---
# Check variables of node ETH_PROP_PLANTS : --- 0.0 seconds ---
# Check variables of node DME_STORAGE : --- 0.0 seconds ---
# Check variables of node DME_PLANTS : --- 0.0 seconds ---
# Check variables of node H2O_STORAGE : --- 0.0 seconds ---
# Check variables of node DESALINATION : --- 0.0 seconds ---
# Check variables of node PCCC_MEOH : --- 0.0 seconds ---
# Check variables of node PCCC_FT : --- 0.0 seconds ---
# Check variables of node PCCC_DME : --- 0.0 seconds ---
# Check variables of node DAC : --- 0.0 seconds ---
# Check variables of node H2_STORAGE : --- 0.0 seconds ---
# Check variables of node H2_INTERCONNECTION_FR : --- 0.0 seconds ---
# Check variables of node H2_INTERCONNECTION_UK : --- 0.0 seconds ---
# Check variables of node H2_INTERCONNECTION_NV : --- 0.0 seconds ---
# Check variables of node H2_INTERCONNECTION : --- 0.0 seconds ---
# Check variables of node REGAS_H2 : --- 0.0 seconds ---
# Check variables of node ELECTROLYSIS_PLANTS : --- 0.0 seconds ---
# Check variables of node METHANATION : --- 0.0 seconds ---
# Check variables of node REGAS_GREEN : --- 0.0 seconds ---
# Check variables of node NG_INTERCONNECTION_FR : --- 0.0 seconds ---
# Check variables of node NG_INTERCONNECTION_UK : --- 0.0 seconds ---
# Check variables of node NG_INTERCONNECTION_NV : --- 0.0 seconds ---
# Check variables of node REGAS : --- 0.0 seconds ---
# Check variables of node FUEL_CELLS : --- 0.0 seconds ---
# Check variables of node BATTERIES : --- 0.0 seconds ---
# Check hyperlink BALANCES : --- 0.0 seconds ---
# Check hyperlink CO2_CAPTURE_MEOH : --- 0.0 seconds ---
# Check hyperlink CO2_CAPTURE_FT : --- 0.0 seconds ---
# Check hyperlink CO2_CAPTURE_DME : --- 0.0 seconds ---
# Check variables of node UNITED_KINGDOM : --- 0.0 seconds ---
# Check variables of node PRODUCTION : --- 0.0 seconds ---
# Check variables of node NUCLEAR : --- 0.0 seconds ---
# Check variables of node WIND_ONSHORE : --- 0.0 seconds ---
# Check variables of node WIND_OFFSHORE : --- 0.0 seconds ---
# Check variables of node PV : --- 0.0 seconds ---
# Check hyperlink IMPORT : --- 0.0 seconds ---
# Check variables of node DENMARK : --- 0.0 seconds ---
# Check variables of node PRODUCTION : --- 0.0 seconds ---
# Check variables of node WIND_ONSHORE : --- 0.01512908935546875 seconds ---
# Check variables of node WIND_OFFSHORE : --- 0.0 seconds ---
# Check variables of node PV : --- 0.0 seconds ---
# Check hyperlink IMPORT : --- 0.0 seconds ---
# Check variables of node HV_OFF_ZB : --- 0.0 seconds ---
# Check variables of node OFFSHORE : --- 0.0 seconds ---
# Check variables of node BALANCE : --- 0.0 seconds ---
# Check variables of node H2O_STORAGE : --- 0.0010528564453125 seconds ---
# Check variables of node DESALINATION : --- 0.0 seconds ---
# Check variables of node H2_STORAGE : --- 0.0 seconds ---
# Check variables of node ELECTROLYSIS_PLANTS : --- 0.0 seconds ---
# Check variables of node FUEL_CELLS : --- 0.0 seconds ---
# Check variables of node BATTERIES : --- 0.0 seconds ---
# Check variables of node WIND_OFFSHORE : --- 0.0 seconds ---
# Check hyperlink BALANCES : --- 0.0 seconds ---
# Check hyperlink CO2_QUOTA : --- 0.0 seconds ---
# Warning : Hyperedge constraint using variables from a single node at line 1693
# Warning : Hyperedge constraint using variables from a single node at line 1695
# Warning : Hyperedge constraint using variables from a single node at line 1698
# Warning : Hyperedge constraint using variables from a single node at line 1703
# Check hyperlink INLAND_BALANCE : --- 0.0 seconds ---
# Check hyperlink DEMAND_SPLIT : --- 0.0 seconds ---
# Warning : Hyperedge constraint using variables from a single node at line 876
# Check hyperlink ZEEBRUGGE_BALANCE : --- 0.0 seconds ---
# Check hyperlink OFFSHORE_BALANCE : --- 0.0 seconds ---
# ⚠️ Gurobi model not found. Make sure build_model() was called.
# 📤 Model exported to 'debug_model.lp'
# 🚀 Solving...
#
# Reading Gurobi options from file gurobi.opt
# Options file not found
#
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (win64)
#
# CPU model: 12th Gen Intel(R) Core(TM) i7-1255U, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 8100293 rows, 3874613 columns and 16994560 nonzeros
# Model fingerprint: 0x18ea495d
# Coefficient statistics:
#   Matrix range     [1e-05, 9e+03]
#   Objective range  [1e-06, 3e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e-05, 9e+05]
# Presolve removed 4861954 rows and 1370000 columns (presolve time = 5s) ...
# Presolve removed 5938525 rows and 2446571 columns (presolve time = 10s) ...
# Presolve removed 5999872 rows and 2464485 columns
# Presolve time: 24.41s
# Presolved: 2100421 rows, 1427646 columns, 7391904 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Elapsed ordering time = 7s
# Elapsed ordering time = 10s
# Ordering time: 27.71s
#
# Barrier statistics:
#  Dense cols : 92
#  AA' NZ     : 1.307e+07
#  Factor NZ  : 1.027e+08 (roughly 2.3 GB of memory)
#  Factor Ops : 3.536e+10 (roughly 1 second per iteration)
#  Threads    : 8
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   6
#   102317 DPushes remaining with DInf 3.1250270e-02               566s
#    94008 DPushes remaining with DInf 3.1250270e-02               571s
#    80609 DPushes remaining with DInf 2.9796214e-02               576s
#    78509 DPushes remaining with DInf 2.9796214e-02               582s
#    77109 DPushes remaining with DInf 2.9796214e-02               585s
#    74309 DPushes remaining with DInf 2.9796214e-02               591s
#    71502 DPushes remaining with DInf 2.9796214e-02               596s
#    70102 DPushes remaining with DInf 2.9796214e-02               601s
#    68702 DPushes remaining with DInf 2.9796214e-02               607s
#    67301 DPushes remaining with DInf 2.9796214e-02               612s
#    65901 DPushes remaining with DInf 2.9796214e-02               617s
#    64501 DPushes remaining with DInf 2.9796214e-02               622s
#    63101 DPushes remaining with DInf 2.9796214e-02               626s
#    51028 DPushes remaining with DInf 2.9796214e-02               630s
#    41012 DPushes remaining with DInf 2.8415201e-02               636s
#    31020 DPushes remaining with DInf 2.8415195e-02               642s
#    13101 DPushes remaining with DInf 2.8415614e-02               646s
#     2112 DPushes remaining with DInf 2.6166162e-02               650s
#        0 DPushes remaining with DInf 2.3799762e-02               654s
#
#   300809 PPushes remaining with PInf 5.1586169e-01               654s
#   139307 PPushes remaining with PInf 5.5024340e-01               665s
#   116851 PPushes remaining with PInf 5.3297647e-01               675s
#   110442 PPushes remaining with PInf 5.5486751e-01               680s
#   104846 PPushes remaining with PInf 5.4925477e-01               685s
#   102534 PPushes remaining with PInf 5.4924028e-01               688s
#    99498 PPushes remaining with PInf 5.4924029e-01               690s
#    94721 PPushes remaining with PInf 5.4909552e-01               697s
#    77928 PPushes remaining with PInf 4.8078485e-01               765s
#    66360 PPushes remaining with PInf 2.0630306e-01               772s
#    63230 PPushes remaining with PInf 2.0630307e-01               776s
#    61243 PPushes remaining with PInf 2.0630306e-01               783s
#    60543 PPushes remaining with PInf 2.0630307e-01               787s
#    27171 PPushes remaining with PInf 6.1634476e-02               808s
#     9211 PPushes remaining with PInf 4.3785151e-02               866s
#        2 PPushes remaining with PInf 1.7221273e-02               871s
#        0 PPushes remaining with PInf 0.0000000e+00               873s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 1.0751930e+02    874s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   531455    9.8596874e+05   0.000000e+00   1.075193e+02    875s
#   532157    9.8596169e+05   0.000000e+00   2.243806e-03    885s
#   532857    9.8596169e+05   0.000000e+00   1.302205e-03    907s
#   533219    9.8596169e+05   2.065232e-06   0.000000e+00    920s
#
# Solved with barrier
#   533220    9.8596169e+05   0.000000e+00   5.025311e+03    929s
#   534505    9.8596169e+05   0.000000e+00   7.602623e-01    973s
# Extra simplex iterations after uncrush: 2141
#   535361    9.8596169e+05   0.000000e+00   0.000000e+00    995s
#
# Solved in 535361 iterations and 994.59 seconds (946.12 work units)
# Optimal objective  9.859616897e+05
# 🧠 Gurobi status: optimal
# ✅ Optimal solution found.
# 📁 Results saved: c:\Users\yaita\OneDrive\Bureau\Master Thesis\Belgium Model - efuel integrated\Simulations\scenario_efuel_INLAND_ZEEBRUGGE_no_ft__1years.json.json and CSV version.
# ✅ Scenario 'efuel_INLAND_ZEEBRUGGE_no_ft' completed in 1108.0 seconds.
